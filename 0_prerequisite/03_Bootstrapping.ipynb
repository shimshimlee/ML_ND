# %%
import numpy as np
np.random.seed(42)

die_vals = np.array([1,2,3,4,5,6])

# %%
np.random.choice(die_vals, size=20)
# Out:
# array([4, 5, 3, 5, 5, 2, 3, 3, 3, 5, 4, 3, 6, 5, 2, 4, 6, 6, 2, 4])

# %%
sample = _
sample.mean()
# Out:
# 4.0

# %%
means = [np.random.choice(die_vals, size=20).mean() for _ in range (10000)]

# %%
import matplotlib.pyplot as plt
plt.hist(means)
# Out:
# (array([  65.,  312.,  972., 1922., 2465., 2250., 1332.,  524.,  131.,
#           27.]),
#  array([2.3  , 2.555, 2.81 , 3.065, 3.32 , 3.575, 3.83 , 4.085, 4.34 ,
#         4.595, 4.85 ]),
#  <BarContainer object of 10 artists>)
